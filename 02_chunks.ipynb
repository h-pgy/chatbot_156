# %%
import pandas as pd
import os
import unicodedata
from config import DATA_DIR

# %%
csv_path = os.path.join(DATA_DIR, 'clean_scraped_services.csv')
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    permite_pedido_anomimo                                            img_url  \
# 0                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 1                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 2                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 3                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 4                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
#
#                                         service_desc  service_id  ativo  \
# 0                                Adotar cães e gatos        3676   True
# 1     Pombos - Solicitar vistoria em local infestado         816   True
# 2       Morcegos - Reclamar sobre local com morcegos         815   True
# 3      Ratos - Solicitar vistoria em local infestado         814   True
# 4  Escorpião - Solicitar vistoria de local com es...         813   True
#
#                                      subtheme_name theme_name  \
# 0                                Adoção de animais    Animais
# 1  Animais que transmitem doenças ou risco à saúde    Animais
# 2  Animais que transmitem doenças ou risco à saúde    Animais
# 3  Animais que transmitem doenças ou risco à saúde    Animais
# 4  Animais que transmitem doenças ou risco à saúde    Animais
#
#                                          description
# 0  O QUE É\nÉ a adoção de cães e gatos alojados n...
# 1  O QUE É\nÉ a solicitação de vistoria em local ...
# 2  O QUE É\nOrientação, esclarecimento de dúvidas...
# 3  O QUE É\nSolicitação de vistoria em local com ...
# 4  O QUE É\nÉ a solicitação de vistoria em local ...

# %%
exemplo = df.loc[0, 'description']

# %%
def remover_acentos(texto: str) -> str:

    nfkd = unicodedata.normalize("NFD", texto)
    texto_sem_acentos = "".join(
        c for c in nfkd if unicodedata.category(c) != "Mn"
    )
    
    return texto_sem_acentos

def clean_chave(chave:str)->str:

    chave = chave.lower().replace(' ', '_').replace('-', '_').replace(',', '_').replace('__', '_').strip()
    chave = remover_acentos(chave)

    return chave

def clean_pedaco(pedaco:str)->str:

    pedaco = pedaco.strip().replace('\xa0', '').replace('clique aqui', '')
    return pedaco


def parse_description(description:str)->dict[str, str]:

    pedacos = description.split('\n')

    atualizacao = pedacos.pop(-1).replace('Atualizado em:', '').strip()
    criacao  = pedacos.pop(-1).replace('Criado em:', '').strip()

    parsed = {
        'dt_atualizacao' : atualizacao,
        'dt_criacao'    : criacao,
    }

    chave = None
    for i, pedaco in enumerate(pedacos):
        if pedaco.isupper():
            chave = clean_chave(pedaco)
        else:
            if chave:
                if chave not in parsed:
                    parsed[chave] = clean_pedaco(pedaco)
                else:
                    parsed[chave] =  parsed[chave] + '***|||***' + clean_pedaco(pedaco)
    
    return parsed


def chunk_header(chunk:str, chunk_key: str, service_name:str, posit:int|None=None)->str:

    header = f"[{chunk_key.upper()} | {service_name}]"

    if posit is not None:
        header = f"[{chunk_key.upper()} | {posit} | {service_name}]"

    return header + '\n' + chunk


def solve_list_chunks(parsed:dict, chave:str, service_name:str, splited:list[str])->None:

    parsed[chave] = []
    pular_next= False
    posit = 1
    for i, item in enumerate(splited):
        if pular_next:
            pular_next= False
            continue
        if item.endswith(':') and i+1 < len(splited):
            pular_next = True
            item = item + ' ' + splited[i+1]
        parsed[chave].append(chunk_header(item, chave, service_name, posit))
        posit+=1

def add_header_to_chunks(parsed_chunks:dict[str, str], service_name:str)->dict[str, str]:


    parsed = {}
    #reestruturando os chunks para formato de lista e colocando o header
    for chave, pedacos in parsed_chunks.items():

        splited = pedacos.split('***|||***')
        if len(splited)>1:
            solve_list_chunks(parsed, chave, service_name, splited)
        else:
            parsed[chave] = chunk_header(pedacos, chave, service_name)

    return parsed


def chunk_json_pipeline(description:str, service_name:str)->dict[str, str]:

    parsed = parse_description(description)
    parsed_with_headers = add_header_to_chunks(parsed, service_name)

    return parsed_with_headers

# %%
parsed_exemplo = chunk_json_pipeline(exemplo, 'Exemplo de Serviço')
parsed_exemplo
# Out:
# {'dt_atualizacao': '[DT_ATUALIZACAO | Exemplo de Serviço]\n20/10/2025',
#  'dt_criacao': '[DT_CRIACAO | Exemplo de Serviço]\n23/04/2020',
#  'o_que_e': '[O_QUE_E | Exemplo de Serviço]\nÉ a adoção de cães e gatos alojados no Centro Municipal de Adoção. Os animais disponíveis estão castrados, vacinados, vermifugados e microchipados.',
#  'quando_solicitar': '[QUANDO_SOLICITAR | Exemplo de Serviço]\nQuando uma pessoa deseja realizar a adoção de um cão ou gato, consciente de que será o responsável pelo animal em todas as etapas de sua vida, promovendo a guarda responsável, o que inclui alimentação adequada, água, higiene, vacinação, cuidados médico-veterinários, atenção e muito carinho.',
#  'publico_alvo': '[PUBLICO_ALVO | Exemplo de Serviço]\nPessoas maiores de idade que desejam adotar cães ou gatos.',
#  'requisitos_documentos_e_informacoes': ['[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Exemplo de Serviço]\nRequisitos necessários para a solicitação: - Ser maior de idade;',
#   '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Exemplo de Serviço]\n-Para adoção de gatos, éobrigatórioque haja telas nas janelas e varandas (apartamentos e sobrados) e outros meios que impeçam o acesso do animal à rua (casas térreas).',
#   '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 3 | Exemplo de Serviço]\nDocumentos a serem apresentados para a adoção: - Documento de identificação com foto;',
#   '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 4 | Exemplo de Serviço]\n- Comprovante de endereço atualizado (emitido em até 90 dias);',
#   '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 5 | Exemplo de Serviço]\nImportante:Levar coleira (no caso de adoção de cães) ou caixa de transporte (no caso de gatos) para o transporte seguro do animal.'],
#  'prazo_maximo': ['[PRAZO_MAXIMO | 1 | Exemplo de Serviço]\n- Conforme disponibilidade de animais;',
#   '[PRAZO_MAXIMO | 2 | Exemplo de Serviço]\n- A conclusão do processo de adoção possui prazo variável, conforme características de animais e adequação das residências ao animal escolhido.'],
#  'taxas_ou_preco_publico': '[TAXAS_OU_PRECO_PUBLICO | Exemplo de Serviço]\nR$ 34,20 por animal adotado.',
#  'canais_para_solicitar': ['[CANAIS_PARA_SOLICITAR | 1 | Exemplo de Serviço]\nEletrônico (somente para animais provenientes de apreensão de comércio ilegal/animais de raça presumida): - Portal de Atendimento SP156 (você já está aqui).',
#   '[CANAIS_PARA_SOLICITAR | 2 | Exemplo de Serviço]\nPresencial: -Centro Municipal de Adoção de Cães e Gatos -Rua Santa Eulália, 86 - Santana, São Paulo - SP ( para ver endereço no mapa).',
#   '[CANAIS_PARA_SOLICITAR | 3 | Exemplo de Serviço]\n-Atendimento de segunda à sexta-feira, das 09h às 17h; aos sábados e domingos das 09h às 15h, exceto feriados.'],
#  'principais_etapas': ['[PRINCIPAIS_ETAPAS | 1 | Exemplo de Serviço]\nEletrônico (somente para adoção de filhotes provenientes de comércio ilegal, feitas exclusivamente por este canal): 1) Faça login no Portal de Atendimento SP156 (você já está aqui), clicando na caixa cinza do lado direito da tela ou no final da página. Informe seus dados do SP156 ou entre com o seu Gov.br. Caso não tenha cadastro, faça o seu;2) Após informar seu login, você será direcionado para o formulário de solicitação;3) Preencha o formulário com as informações solicitadas( para ser direcionado para o formulário diretamente. Lembre-se que é necessário realizar login)e finalize sua solicitação;',
#   '[PRINCIPAIS_ETAPAS | 2 | Exemplo de Serviço]\n4) Escolha o cão e/ou gato que deseja adotar acessando o link abaixo: -Cães disponíveis para adoção -  para consultar (link direciona para portal externo).',
#   '[PRINCIPAIS_ETAPAS | 3 | Exemplo de Serviço]\n-Gatos disponíveis para adoção -  para consultar (link direciona para portal externo).',
#   '[PRINCIPAIS_ETAPAS | 4 | Exemplo de Serviço]\n5) Preencha o formulário de solicitação informando o nome do animal que deseja adotar. Durante o preenchimento do formulário você também terá acesso às fotos e descrições dos animais;',
#   '[PRINCIPAIS_ETAPAS | 5 | Exemplo de Serviço]\n6) A sua solicitação será registrada e encaminhada à equipe responsável pelo serviço de adoção;',
#   '[PRINCIPAIS_ETAPAS | 6 | Exemplo de Serviço]\n7) Após análise da solicitação, você receberá informações agendando o dia de comparecimento ao Centro Municipal de Adoção de Cães e Gatos para realizar entrevista e conhecer o animal desejado;',
#   '[PRINCIPAIS_ETAPAS | 7 | Exemplo de Serviço]\n8) Acompanhe sua solicitação por meio de seu número de protocolo pelo \u202fPortal SP156 em "Acompanhe Sua Solicitação".',
#   '[PRINCIPAIS_ETAPAS | 8 | Exemplo de Serviço]\nPresencial: 1) Compareça ao Centro Municipal de Adoção de Cães e Gatos que está localizado naRua Santa Eulália, 86 - Santana, São Paulo - SP ( para ver no mapa - link direciona para portal externo).Atendimento de segunda à sexta-feira, das 09h às 17h; aos sábados e domingos das 09h às 15h, exceto feriados;',
#   '[PRINCIPAIS_ETAPAS | 9 | Exemplo de Serviço]\n2) Você conhecerá os animais disponíveis e passará por uma entrevista para avaliar a compatibilidade entre o perfil do animal escolhido e da pessoa/família. Procura-se entender a situação familiar e encontrar a melhor opção de adoção; pode ocorrer do animal escolhido não ser liberado devido às características individuais da família e do animal;',
#   '[PRINCIPAIS_ETAPAS | 10 | Exemplo de Serviço]\n3) Se necessário, será realizada visita prévia à sua residência;',
#   '[PRINCIPAIS_ETAPAS | 11 | Exemplo de Serviço]\n4) Após a aprovação da adoção, é emitido o RGA do animal e o pagamento da taxa pública correspondente à adoção;',
#   '[PRINCIPAIS_ETAPAS | 12 | Exemplo de Serviço]\n5) Visita pós-adoção poderá ser realizada para acompanhamento do animal, sem aviso prévio;',
#   '[PRINCIPAIS_ETAPAS | 13 | Exemplo de Serviço]\n6) Há um prazo de 30 dias para adaptação entre o animal e a família.'],
#  'legislacao': '[LEGISLACAO | Exemplo de Serviço]\n-Lei Municipal nº 13.131/2001 ( para acessar - link direciona para portal externo).',
#  'observacoes': ['[OBSERVACOES | 1 | Exemplo de Serviço]\n-Mais informações sobre o Centro Municipal de adoção de Cães e Gatos ( para acessar - link direciona para portal externo);',
#   '[OBSERVACOES | 2 | Exemplo de Serviço]\n-Outras informações ( para acessar - link direciona para portal externo).'],
#  'orgao_responsavel': ['[ORGAO_RESPONSAVEL | 1 | Exemplo de Serviço]\n- Coordenadoria de Saúde e Proteção ao Animal Doméstico (COSAP);',
#   '[ORGAO_RESPONSAVEL | 2 | Exemplo de Serviço]\n- Secretaria Municipal da Saúde (SMS).'],
#  'manifestacao_sobre_o_servico': '[MANIFESTACAO_SOBRE_O_SERVICO | Exemplo de Serviço]\nÉ possível registrar reclamação, elogio ou sugestão sobre este serviço junto à Ouvidoria SUS( para acessar - link direciona para portal externo).'}

# %%
def flaten_chunks(parsed_json:dict)->list[str]:

    flatened = []
    for pedacos in parsed_json.values():
        if isinstance(pedacos, list):
            for pedaco in pedacos:
                flatened.append(pedaco)
        else:
            flatened.append(pedacos)
    
    return flatened

# %%
chunks = flaten_chunks(parsed_exemplo)

# %%
chunks[0]
# Out:
# '[DT_ATUALIZACAO | Exemplo de Serviço]\n20/10/2025'

# %%
df.head()
# Out:
#    permite_pedido_anomimo                                            img_url  \
# 0                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 1                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 2                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 3                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 4                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
#
#                                         service_desc  service_id  ativo  \
# 0                                Adotar cães e gatos        3676   True
# 1     Pombos - Solicitar vistoria em local infestado         816   True
# 2       Morcegos - Reclamar sobre local com morcegos         815   True
# 3      Ratos - Solicitar vistoria em local infestado         814   True
# 4  Escorpião - Solicitar vistoria de local com es...         813   True
#
#                                      subtheme_name theme_name  \
# 0                                Adoção de animais    Animais
# 1  Animais que transmitem doenças ou risco à saúde    Animais
# 2  Animais que transmitem doenças ou risco à saúde    Animais
# 3  Animais que transmitem doenças ou risco à saúde    Animais
# 4  Animais que transmitem doenças ou risco à saúde    Animais
#
#                                          description
# 0  O QUE É\nÉ a adoção de cães e gatos alojados n...
# 1  O QUE É\nÉ a solicitação de vistoria em local ...
# 2  O QUE É\nOrientação, esclarecimento de dúvidas...
# 3  O QUE É\nSolicitação de vistoria em local com ...
# 4  O QUE É\nÉ a solicitação de vistoria em local ...

# %%
all_chunks = []
metadata_list = []
for i, row in df.iterrows():
    description = row['description']
    service_name = row['service_desc']
    parsed_chunks = chunk_json_pipeline(description, service_name)
    chunks = flaten_chunks(parsed_chunks)
    all_chunks.extend(chunks)
    metadata_list.extend([{
                           "service_name": service_name,
                           "service_id" : row['service_id'],
                            "theme" : row['theme_name'],
                            "subtheme" : row['subtheme_name']
                                              }] * len(chunks))

# %%
assert len(all_chunks) == len(metadata_list)

# %%
import json

# %%
dados = {
    "chunks": all_chunks,
    "metadata": metadata_list}

# %%
json_path = os.path.join(DATA_DIR, 'chunks_metadata.json')
with open(json_path, 'w') as f:
    json.dump(dados, f, ensure_ascii=False, indent=4)
