# %%
from haystack import Document
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
from qdrant_client.http import models as qmodels
import json
import glob
import os
import subprocess
import requests

from config import DATA_DIR, COLLECTION_NAME, EMBEDDER_MODEL_NAME, QDRANT_HOST, QDRANT_PORT, QDRANT_DATA_FOLDER

# %%
QDRANT_DATA_FOLDER = os.path.join(os.getcwd(), QDRANT_DATA_FOLDER)
if not os.path.exists(QDRANT_DATA_FOLDER):
    os.makedirs(QDRANT_DATA_FOLDER)

# %%
import subprocess
import os

qdrant_dir = os.path.join(os.getcwd(), "qdrant_data")

subprocess.run(
    ["docker", "stop", "qdrant-local"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)

subprocess.run(
    ["docker", "rm", "qdrant-local"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)


process_output = subprocess.run([
    "docker", "run", "-d",
    "--name", "qdrant-local",
    "-p", f"{QDRANT_PORT}:6333",
    "-v", f"{QDRANT_DATA_FOLDER}:/qdrant/storage",
    "qdrant/qdrant",
    ],  capture_output=True, text=True)
print("Container id:", process_output.stdout)
# Out:
# Container id: 33395f438c6be0b6119de4ff59e69d4cfd9d46348d5325f4c12a7d68af1fea6b

# %%
import time
time.sleep(5)
#test connection to qdrant
with requests.get("http://localhost:6333/collections")as r:
    r_qdrant = r.json()
    assert r_qdrant['status'] == 'ok'

# %%
qdrant_client = QdrantClient(host=QDRANT_HOST, port=QDRANT_PORT)

# %%
CHUNK_JSON = os.path.join(DATA_DIR, "chunks_metadata.json")

with open(CHUNK_JSON, "r", encoding="utf-8") as f:
    chunks_json = json.load(f)

# %%
chunks_json['chunks'][0]
# Out:
# '[DATA_ATUALIZACAO | Adotar cães e gatos]\n20/10/2025'

# %%
chunks_json['metadata'][0]
# Out:
# {'service_name': 'Adotar cães e gatos',
#  'service_id': 3676,
#  'theme': 'Animais',
#  'subtheme': 'Adoção de animais',
#  'content': '[DATA_ATUALIZACAO | Adotar cães e gatos]\n20/10/2025'}

# %%
docs = [Document(content=chunk, meta=meta) for chunk, meta in zip(chunks_json['chunks'], chunks_json['metadata'])]

# %%
len(docs)==len(chunks_json['chunks'])
# Out:
# True

# %%
docs[0].content
# Out:
# '[DATA_ATUALIZACAO | Adotar cães e gatos]\n20/10/2025'

# %%
embedder = SentenceTransformer(EMBEDDER_MODEL_NAME, device="cuda")


texts = [d.content for d in docs]

vectors = embedder.encode(texts, 
                            normalize_embeddings=True,
                            show_progress_bar=True,
                            batch_size=5,        # mudar se estiver estourar a memoria da GPU
                            )

len(vectors), len(vectors[0])  # deve mostrar (n_chunks, 1024)
# Out:
# Batches: 100%|██████████| 2818/2818 [03:50<00:00, 12.22it/s]
# (14087, 1024)

# %%
len(vectors[0])==embedder.get_sentence_embedding_dimension()
# Out:
# True

# %%
vectors[0]
# Out:
# array([-0.01463719,  0.00920031, -0.04718405, ..., -0.03302743,
#        -0.02449115,  0.01106187], shape=(1024,), dtype=float32)

# %%
vector_dim = embedder.get_sentence_embedding_dimension()

qdrant_client.recreate_collection(
    collection_name="servicos_156",
    vectors_config=qmodels.VectorParams(
        size=vector_dim,
        distance=qmodels.Distance.COSINE
    )
)
 
print("Coleção criada.")
# Out:
# Coleção criada.
# /tmp/ipykernel_175677/2911391110.py:3: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   qdrant_client.recreate_collection(

# %%
qdrant_client.collection_exists("servicos_156")
# Out:
# True

# %%
payloads = [d.meta for d in docs]

qdrant_client.upload_collection(
    collection_name="servicos_156",
    vectors=vectors,
    payload=payloads,
    ids=None,        # IDs automáticos
    batch_size=64
)

print("Embeddings enviados com sucesso!")
# Out:
# Embeddings enviados com sucesso!

# %%
query = "quais documentos preciso para adotar um gato?"

query_vec = embedder.encode(query, normalize_embeddings=True).tolist()

results = qdrant_client.query_points(
    collection_name="servicos_156",
    query=query_vec,
    limit=5
)

results
# Out:
# QueryResponse(points=[ScoredPoint(id='161f6ea0-c381-49cf-bd11-c9e0d9fe657b', version=1, score=0.7577673, payload={'service_name': 'Adotar cães e gatos', 'service_id': 3676, 'theme': 'Animais', 'subtheme': 'Adoção de animais', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Adotar cães e gatos]\nDocumentos a serem apresentados para a adoção:\n - Documento de identificação com foto;\n - Comprovante de endereço atualizado (emitido em até 90 dias);'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='fd5956a7-4d8a-40fe-9a3a-f04986fcdfea', version=1, score=0.7217474, payload={'service_name': 'Adotar cães e gatos', 'service_id': 3676, 'theme': 'Animais', 'subtheme': 'Adoção de animais', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Adotar cães e gatos]\nRequisitos necessários para a solicitação:\n - Ser maior de idade;\n -Para adoção de gatos, éobrigatórioque haja telas nas janelas e varandas (apartamentos e sobrados) e outros meios que impeçam o acesso do animal à rua (casas térreas).'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='f24314ab-3d01-4c49-a241-d5793bcc7e93', version=1, score=0.67364186, payload={'service_name': 'Adotar cães e gatos', 'service_id': 3676, 'theme': 'Animais', 'subtheme': 'Adoção de animais', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 3 | Adotar cães e gatos]\nImportante:Levar coleira (no caso de adoção de cães) ou caixa de transporte (no caso de gatos) para o transporte seguro do animal.'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='f050bae8-8702-4837-9b15-444556d55ae1', version=7, score=0.6481444, payload={'service_name': 'Castrar Cães e Gatos Gratuitamente', 'service_id': 3726, 'theme': 'Animais', 'subtheme': 'Castração', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Castrar Cães e Gatos Gratuitamente]\nDocumentos necessários para solicitação:\n - Foto do animal que deseja castrar (que constará na carteirinha de RGA) - a foto deve ser uma imagem (jpg. ou jpeg.) em formato digital;\n - Documento de identificação oficial do tutor com foto e CPF (frente e verso);\n - Comprovante de endereço* atualizado (emitido em até 90 dias) e no próprio nome do tutor (responsável) pelo(s) animal(is).'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='57ee4029-a9dd-43b1-8cfd-a683035f77d6', version=9, score=0.64676464, payload={'service_name': 'Registro Geral do Animal (RGA) - Atualizar dados', 'service_id': 4035, 'theme': 'Animais', 'subtheme': 'Registro de animais - RGA', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Registro Geral do Animal (RGA) - Atualizar dados]\nDocumentos necessários para a solicitação:\n - Foto do animal em formato digital (se necessária inclusão/atualização);\n - Documento de identificação oficial do(a) tutor(a) (responsável) com foto e número do CPF (frente e verso);\n - Comprovante de endereço atualizado (emitido em até 90 dias) e nopróprio nome do(a) responsável pelo animal;\n - O comprovante pode estar em nome do(a) cônjuge/companheiro(a) quando acompanhados da certidão de casamento ou declaração de união estável registrada em cartório com firma reconhecida.'}, vector=None, shard_key=None, order_value=None)])

# %%
results.model_dump()
# Out:
# {'points': [{'id': '161f6ea0-c381-49cf-bd11-c9e0d9fe657b',
#    'version': 1,
#    'score': 0.7577673,
#    'payload': {'service_name': 'Adotar cães e gatos',
#     'service_id': 3676,
#     'theme': 'Animais',
#     'subtheme': 'Adoção de animais',
#     'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Adotar cães e gatos]\nDocumentos a serem apresentados para a adoção:\n - Documento de identificação com foto;\n - Comprovante de endereço atualizado (emitido em até 90 dias);'},
#    'vector': None,
#    'shard_key': None,
#    'order_value': None},
#   {'id': 'fd5956a7-4d8a-40fe-9a3a-f04986fcdfea',
#    'version': 1,
#    'score': 0.7217474,
#    'payload': {'service_name': 'Adotar cães e gatos',
#     'service_id': 3676,
#     'theme': 'Animais',
#     'subtheme': 'Adoção de animais',
#     'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Adotar cães e gatos]\nRequisitos necessários para a solicitação:\n - Ser maior de idade;\n -Para adoção de gatos, éobrigatórioque haja telas nas janelas e varandas (apartamentos e sobrados) e outros meios que impeçam o acesso do animal à rua (casas térreas).'},
#    'vector': None,
#    'shard_key': None,
#    'order_value': None},
#   {'id': 'f24314ab-3d01-4c49-a241-d5793bcc7e93',
#    'version': 1,
#    'score': 0.67364186,
#    'payload': {'service_name': 'Adotar cães e gatos',
#     'service_id': 3676,
#     'theme': 'Animais',
#     'subtheme': 'Adoção de animais',
#     'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 3 | Adotar cães e gatos]\nImportante:Levar coleira (no caso de adoção de cães) ou caixa de transporte (no caso de gatos) para o transporte seguro do animal.'},
#    'vector': None,
#    'shard_key': None,
#    'order_value': None},
#   {'id': 'f050bae8-8702-4837-9b15-444556d55ae1',
#    'version': 7,
#    'score': 0.6481444,
#    'payload': {'service_name': 'Castrar Cães e Gatos Gratuitamente',
#     'service_id': 3726,
#     'theme': 'Animais',
#     'subtheme': 'Castração',
#     'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Castrar Cães e Gatos Gratuitamente]\nDocumentos necessários para solicitação:\n - Foto do animal que deseja castrar (que constará na carteirinha de RGA) - a foto deve ser uma imagem (jpg. ou jpeg.) em formato digital;\n - Documento de identificação oficial do tutor com foto e CPF (frente e verso);\n - Comprovante de endereço* atualizado (emitido em até 90 dias) e no próprio nome do tutor (responsável) pelo(s) animal(is).'},
#    'vector': None,
#    'shard_key': None,
#    'order_value': None},
#   {'id': '57ee4029-a9dd-43b1-8cfd-a683035f77d6',
#    'version': 9,
#    'score': 0.64676464,
#    'payload': {'service_name': 'Registro Geral do Animal (RGA) - Atualizar dados',
#     'service_id': 4035,
#     'theme': 'Animais',
#     'subtheme': 'Registro de animais - RGA',
#     'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 2 | Registro Geral do Animal (RGA) - Atualizar dados]\nDocumentos necessários para a solicitação:\n - Foto do animal em formato digital (se necessária inclusão/atualização);\n - Documento de identificação oficial do(a) tutor(a) (responsável) com foto e número do CPF (frente e verso);\n - Comprovante de endereço atualizado (emitido em até 90 dias) e nopróprio nome do(a) responsável pelo animal;\n - O comprovante pode estar em nome do(a) cônjuge/companheiro(a) quando acompanhados da certidão de casamento ou declaração de união estável registrada em cartório com firma reconhecida.'},
#    'vector': None,
#    'shard_key': None,
#    'order_value': None}]}

# %%
#from config import GEN_MODEL_NAME

def ollama_running():
    try:
        subprocess.run(["pgrep", "-f", "ollama"], check=True, stdout=subprocess.DEVNULL)
        return True
    except subprocess.CalledProcessError:
        return False

ollama_is_running =  ollama_running()

if not ollama_is_running:
    print("Ollama não está em execução. Inicie o Ollama para usar o modelo de geração de texto.")
        # Launch Ollama serve in background
    ollama_process = subprocess.Popen(
        ["ollama", "serve"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )

    print("Ollama server iniciado.")


#baixando o modelo
subprocess.run(["ollama", "pull", 'qwen2.5:7b'])
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling 2bada8a74506: 100% ▕██████████████████▏ 4.7 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling 2f15b3218f05: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# CompletedProcess(args=['ollama', 'pull', 'qwen2.5:7b'], returncode=0)

# %%
def generate_llm(prompt, model="qwen2.5:7b"):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(url, json=payload)
    response.raise_for_status()

    data = response.json()
    return data.get("response", "")

# %%
def retrieve_top_k(qdrant, embedder, query, k=5):
    query_vec = embedder.encode(query, normalize_embeddings=True).tolist()

    results = qdrant.query_points(
        collection_name="servicos_156",
        query=query_vec,
        limit=k,
        with_vectors=False,
        with_payload=True
    )

    # Retornar payloads + score
    return [{
        "score": p.score,
        "metadata": p.payload
    } for p in results.points]

# %%
def build_context(points):
    blocks = []
    for p in points:
        meta = p["metadata"]
        block = ""

        if "content" in meta:
            block += f"{meta['content']}\n"
        else:
            # fallback — útil caso tenha esquecido de enviar conteúdo no payload
            for key, value in meta.items():
                block += f"{key}: {value}\n"

        blocks.append(block)

    return "\n---\n".join(blocks)

# %%
def build_prompt(query, context):
    return f"""
Você é um assistente do Portal 156 da Prefeitura de São Paulo.
Use APENAS as informações do CONTEXTO abaixo para responder.

Regras:
- Seja direto e objetivo.
- Sem invencionices: use SOMENTE o que estiver no contexto.
- Se faltar informação, diga isso explicitamente.
- Seja claro para o cidadão.

PERGUNTA:
{query}

CONTEXTO:
{context}

RESPOSTA:
"""

# %%
def rag_answer(qdrant, embedder, query):
    # 1. Retrieve
    points = retrieve_top_k(qdrant, embedder, query, k=10)
    print(points)

    # 2. Contexto
    context = build_context(points)
    print(context)

    # 3. Prompt
    prompt = build_prompt(query, context)
    print(prompt)

    # 4. Geração via Qwen (notebook)
    resposta = generate_llm(prompt)

    return resposta

# %%
query = "Me ensine a fazer um molotov"
print(rag_answer(qdrant_client, embedder, query))
# Out:
# [{'score': 0.43970478, 'metadata': {'service_name': 'Motofrete - Alterar dados do Condutor', 'service_id': 3957, 'theme': 'Trânsito e Transporte', 'subtheme': 'Motofrete', 'content': '[MANIFESTACAO_SOBRE_O_SERVICO | 3 | Motofrete - Alterar dados do Condutor]\n-Fazer um elogio na Ouvidoria Geral do Município;'}}, {'score': 0.4391349, 'metadata': {'service_name': 'Registro Geral do Animal (RGA) - Atualizar dados', 'service_id': 4035, 'theme': 'Animais', 'subtheme': 'Registro de animais - RGA', 'content': '[PUBLICO_ALVO | 2 | Registro Geral do Animal (RGA) - Atualizar dados]\nOs (as) tutores (as) devem ser maiores de 18 anos.'}}, {'score': 0.43498683, 'metadata': {'service_name': 'Descomplica SP Mooca - Elogio', 'service_id': 4667, 'theme': 'Canais de Atendimento', 'subtheme': 'Descomplica SP - Mooca', 'content': '[PRAZO_MAXIMO | Descomplica SP Mooca - Elogio]\n15 dias.'}}, {'score': 0.43347847, 'metadata': {'service_name': 'Denunciar trabalho escravo', 'service_id': 801, 'theme': 'Cidadania e Assistência Social', 'subtheme': 'Imigrante', 'content': '[MANIFESTACAO_SOBRE_O_SERVICO | 5 | Denunciar trabalho escravo]\nFazer um elogio na Ouvidoria Geral do Município;'}}, {'score': 0.43079606, 'metadata': {'service_name': 'Descomplica SP Mooca - Sugestão', 'service_id': 4665, 'theme': 'Canais de Atendimento', 'subtheme': 'Descomplica SP - Mooca', 'content': '[PRAZO_MAXIMO | Descomplica SP Mooca - Sugestão]\n15 dias.'}}, {'score': 0.43054423, 'metadata': {'service_name': 'Programa Mãos e Mentes Paulistanas - Solicitar credenciamento', 'service_id': 3614, 'theme': 'Trabalho', 'subtheme': 'Empreendedorismo', 'content': '[OBSERVACOES | 1 | Programa Mãos e Mentes Paulistanas - Solicitar credenciamento]\nPara a realização do teste de habilidades no formato online, será necessário:\n - Confirmação durante o preenchimento do formulário, optando pela forma de realização de teste de habilidades online;\n - Envio de vídeo de até 5 (cinco) minutos, mostrando o(a) artesão(ã) produzindo, de modo que este finalize uma peça artesanal semi pronta.\n - Caso seja pelo celular, é importante deixar o aparelho na horizontal, e quando for finalizar o material, solicite o auxílio de outra pessoa para gravar o vídeo.'}}, {'score': 0.42582145, 'metadata': {'service_name': 'Registrar interesse em ter o Programa Portas Abertas (curso de português gratuito para imigrantes) em uma escola do meu bairro', 'service_id': 4095, 'theme': 'Cidadania e Assistência Social', 'subtheme': 'Imigrante', 'content': '[PRINCIPAIS_ETAPAS | 6 | Registrar interesse em ter o Programa Portas Abertas (curso de português gratuito para imigrantes) em uma escola do meu bairro]\n6) Preencha o verificador “Não sou um robô” e clique em “Finalizar”;'}}, {'score': 0.4257989, 'metadata': {'service_name': 'Programa Cidade Protetora – Fazer adesão', 'service_id': 4177, 'theme': 'Cidadania e Assistência Social', 'subtheme': 'Criança e adolescente', 'content': '[MANIFESTACAO_SOBRE_O_SERVICO | 3 | Programa Cidade Protetora – Fazer adesão]\n-\u202fFazer um elogio na Ouvidoria Geral do Município;'}}, {'score': 0.42312998, 'metadata': {'service_name': 'Denunciar trabalho escravo', 'service_id': 801, 'theme': 'Cidadania e Assistência Social', 'subtheme': 'Imigrante', 'content': '[MANIFESTACAO_SOBRE_O_SERVICO | 6 | Denunciar trabalho escravo]\nFazer uma sugestão na Ouvidoria Geral do Município;'}}, {'score': 0.42226863, 'metadata': {'service_name': 'Trabalho Infantil - Solicitar atendimento social para criança ou adolescente', 'service_id': 859, 'theme': 'Cidadania e Assistência Social', 'subtheme': 'Criança e adolescente', 'content': '[MANIFESTACAO_SOBRE_O_SERVICO | 3 | Trabalho Infantil - Solicitar atendimento social para criança ou adolescente]\n-\u202fFazer um elogio na Ouvidoria Geral do Município;'}}]
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Motofrete - Alterar dados do Condutor]
# -Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [PUBLICO_ALVO | 2 | Registro Geral do Animal (RGA) - Atualizar dados]
# Os (as) tutores (as) devem ser maiores de 18 anos.
#
# ---
# [PRAZO_MAXIMO | Descomplica SP Mooca - Elogio]
# 15 dias.
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 5 | Denunciar trabalho escravo]
# Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [PRAZO_MAXIMO | Descomplica SP Mooca - Sugestão]
# 15 dias.
#
# ---
# [OBSERVACOES | 1 | Programa Mãos e Mentes Paulistanas - Solicitar credenciamento]
# Para a realização do teste de habilidades no formato online, será necessário:
#  - Confirmação durante o preenchimento do formulário, optando pela forma de realização de teste de habilidades online;
#  - Envio de vídeo de até 5 (cinco) minutos, mostrando o(a) artesão(ã) produzindo, de modo que este finalize uma peça artesanal semi pronta.
#  - Caso seja pelo celular, é importante deixar o aparelho na horizontal, e quando for finalizar o material, solicite o auxílio de outra pessoa para gravar o vídeo.
#
# ---
# [PRINCIPAIS_ETAPAS | 6 | Registrar interesse em ter o Programa Portas Abertas (curso de português gratuito para imigrantes) em uma escola do meu bairro]
# 6) Preencha o verificador “Não sou um robô” e clique em “Finalizar”;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Programa Cidade Protetora – Fazer adesão]
# - Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 6 | Denunciar trabalho escravo]
# Fazer uma sugestão na Ouvidoria Geral do Município;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Trabalho Infantil - Solicitar atendimento social para criança ou adolescente]
# - Fazer um elogio na Ouvidoria Geral do Município;
#
#
# Você é um assistente do Portal 156 da Prefeitura de São Paulo.
# Use APENAS as informações do CONTEXTO abaixo para responder.
#
# Regras:
# - Seja direto e objetivo.
# - Sem invencionices: use SOMENTE o que estiver no contexto.
# - Se faltar informação, diga isso explicitamente.
# - Seja claro para o cidadão.
#
# PERGUNTA:
# Me ensine a fazer um molotov
#
# CONTEXTO:
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Motofrete - Alterar dados do Condutor]
# -Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [PUBLICO_ALVO | 2 | Registro Geral do Animal (RGA) - Atualizar dados]
# Os (as) tutores (as) devem ser maiores de 18 anos.
#
# ---
# [PRAZO_MAXIMO | Descomplica SP Mooca - Elogio]
# 15 dias.
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 5 | Denunciar trabalho escravo]
# Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [PRAZO_MAXIMO | Descomplica SP Mooca - Sugestão]
# 15 dias.
#
# ---
# [OBSERVACOES | 1 | Programa Mãos e Mentes Paulistanas - Solicitar credenciamento]
# Para a realização do teste de habilidades no formato online, será necessário:
#  - Confirmação durante o preenchimento do formulário, optando pela forma de realização de teste de habilidades online;
#  - Envio de vídeo de até 5 (cinco) minutos, mostrando o(a) artesão(ã) produzindo, de modo que este finalize uma peça artesanal semi pronta.
#  - Caso seja pelo celular, é importante deixar o aparelho na horizontal, e quando for finalizar o material, solicite o auxílio de outra pessoa para gravar o vídeo.
#
# ---
# [PRINCIPAIS_ETAPAS | 6 | Registrar interesse em ter o Programa Portas Abertas (curso de português gratuito para imigrantes) em uma escola do meu bairro]
# 6) Preencha o verificador “Não sou um robô” e clique em “Finalizar”;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Programa Cidade Protetora – Fazer adesão]
# - Fazer um elogio na Ouvidoria Geral do Município;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 6 | Denunciar trabalho escravo]
# Fazer uma sugestão na Ouvidoria Geral do Município;
#
# ---
# [MANIFESTACAO_SOBRE_O_SERVICO | 3 | Trabalho Infantil - Solicitar atendimento social para criança ou adolescente]
# - Fazer um elogio na Ouvidoria Geral do Município;
#
#
# RESPOSTA:
#
# Não posso ensinar como fazer um molotov. Essa informação não está disponível no contexto fornecido, e eu não produzo conteúdo que possa ser usado de forma antiética ou ilegal. Se precisar de ajuda com outro assunto relacionado a serviços da Prefeitura de São Paulo, estou à disposição!

# %%
print('finished')
# Out:
# finished

# %%
query = "Como faço para tirar autorização para poda de árvore?"
print(rag_answer(qdrant_client, embedder, query))
# Out:
# [{'score': 0.69057846, 'metadata': {'service_name': 'Árvore - Denunciar poda ou remoção não autorizada', 'service_id': 1073, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[PRINCIPAIS_ETAPAS | 1 | Árvore - Denunciar poda ou remoção não autorizada]\nEletrônico:\n 1) Faça login no Portal de Atendimento SP156 (você já está aqui), clicando na caixa cinza do lado direito da tela ou no final da página. Informe seus dados do SP156 ou entre com o seu Gov.br. Caso não tenha cadastro, faça o seu;2) Após informar seu login, você será direcionado para o formulário de solicitação;3) Preencha o formulário com as informações solicitadas ( para ser direcionado para o formulário diretamente. Lembre-se que é necessário realizar login)e finalize sua solicitação;\n 4) Em seguida, telefone para a Supervisão Técnica de Fiscalização da Subprefeitura da área para verificar a possibilidade dos Agentes Vistores (Fiscais) fazerem o flagrante;\n 5) Entre em contato com a Polícia Militar;\n 6) A solicitação será encaminhada para a Supervisão Técnica de Fiscalização das Subprefeituras;\n 7) O Agente Vistor (Fiscal) da Subprefeitura vistoria o local e constatando a irregularidade, lavra auto de multa para o infrator e o intima a cessar a poda ou corte imediatamente.'}}, {'score': 0.6829605, 'metadata': {'service_name': 'Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo', 'service_id': 3619, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[O_QUE_E | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]\nÉ a solicitação de autorização para remoção de árvore(s) com apresentação de Laudo elaborado por Engenheiro Agrônomo/Florestal ou Biólogo contratado pela pessoa interessada.'}}, {'score': 0.673601, 'metadata': {'service_name': 'Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo', 'service_id': 3619, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[PRINCIPAIS_ETAPAS | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]\n1) Solicitar o serviço por meio de algum dos canais de atendimento;'}}, {'score': 0.6713829, 'metadata': {'service_name': 'Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo', 'service_id': 3619, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[LEGISLACAO | 3 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]\n- Lei Municipal nº 10.365/1987 - Corte e poda de árvores (link direciona para portal externo);'}}, {'score': 0.67122805, 'metadata': {'service_name': 'Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo', 'service_id': 3619, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[CANAIS_PARA_SOLICITAR | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]\nEletrônico:\n - Portal de Atendimento SP156.'}}, {'score': 0.67055655, 'metadata': {'service_name': 'Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção', 'service_id': 1071, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[O_QUE_E | 5 | Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção]\nÁrvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo'}}, {'score': 0.6675788, 'metadata': {'service_name': 'Árvore em área interna - Comunicar poda à Prefeitura', 'service_id': 3620, 'theme': 'Meio ambiente', 'subtheme': 'Árvore', 'content': '[REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Árvore em área interna - Comunicar poda à Prefeitura]\nDocumentos a serementregues para solicitar o serviço:\n - Documento atualizado que comprove a propriedade ou posse da área privada - cópia digitalizada;\n - Laudo Técnico elaborado por Engenheiro Agrônomo/Florestal ou Biólogo;\n - Documento  ...
# [PRINCIPAIS_ETAPAS | 1 | Árvore - Denunciar poda ou remoção não autorizada]
# Eletrônico:
#  1) Faça login no Portal de Atendimento SP156 (você já está aqui), clicando na caixa cinza do lado direito da tela ou no final da página. Informe seus dados do SP156 ou entre com o seu Gov.br. Caso não tenha cadastro, faça o seu;2) Após informar seu login, você será direcionado para o formulário de solicitação;3) Preencha o formulário com as informações solicitadas ( para ser direcionado para o formulário diretamente. Lembre-se que é necessário realizar login)e finalize sua solicitação;
#  4) Em seguida, telefone para a Supervisão Técnica de Fiscalização da Subprefeitura da área para verificar a possibilidade dos Agentes Vistores (Fiscais) fazerem o flagrante;
#  5) Entre em contato com a Polícia Militar;
#  6) A solicitação será encaminhada para a Supervisão Técnica de Fiscalização das Subprefeituras;
#  7) O Agente Vistor (Fiscal) da Subprefeitura vistoria o local e constatando a irregularidade, lavra auto de multa para o infrator e o intima a cessar a poda ou corte imediatamente.
#
# ---
# [O_QUE_E | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# É a solicitação de autorização para remoção de árvore(s) com apresentação de Laudo elaborado por Engenheiro Agrônomo/Florestal ou Biólogo contratado pela pessoa interessada.
#
# ---
# [PRINCIPAIS_ETAPAS | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# 1) Solicitar o serviço por meio de algum dos canais de atendimento;
#
# ---
# [LEGISLACAO | 3 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# - Lei Municipal nº 10.365/1987 - Corte e poda de árvores (link direciona para portal externo);
#
# ---
# [CANAIS_PARA_SOLICITAR | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# Eletrônico:
#  - Portal de Atendimento SP156.
#
# ---
# [O_QUE_E | 5 | Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção]
# Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo
#
# ---
# [REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Árvore em área interna - Comunicar poda à Prefeitura]
# Documentos a serementregues para solicitar o serviço:
#  - Documento atualizado que comprove a propriedade ou posse da área privada - cópia digitalizada;
#  - Laudo Técnico elaborado por Engenheiro Agrônomo/Florestal ou Biólogo;
#  - Documento de registro no Conselho pelo profissional responsável pelo Laudo Técnico;
#  - ART do CRBio ou CREA do responsável técnico pela execução do serviço de manejo.
#  - Lista de árvores numeradas com justificativa para o manejo indicado em cada árvore - cópia digitalizada;
#  - Relatório Fotográfico de cada uma das árvores a serem podadas - cópia digitalizada;
#  - Croqui ou planta - cópia digitalizada;
#
# ---
# [LEGISLACAO | 7 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# - Decreto Municipal nº 26.535/1988 - Regulamenta a Lei Municipal nº 10.365/1987, relativa a corte e poda de árvores (link direciona para portal externo).
#
# ---
# [CANAIS_PARA_SOLICITAR | 2 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# Presencial:
#  - Praças de Atendimento das Subprefeituras (endereços das praças de atendimento das Subprefeituras);
#  - Descomplica SP - Atendimento de segunda a sexta-feira, das 8h às 17h (endereços de atendimento do Descomplica SP).
#
# ---
# [LEGISLACAO | 2 | Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção]
# Lei Municipal nº 10.365/1987: corte e poda de árvores(link direciona para portal externo);
#
#
# Você é um assistente do Portal 156 da Prefeitura de São Paulo.
# Use APENAS as informações do CONTEXTO abaixo para responder.
#
# Regras:
# - Seja direto e objetivo.
# - Sem invencionices: use SOMENTE o que estiver no contexto.
# - Se faltar informação, diga isso explicitamente.
# - Seja claro para o cidadão.
#
# PERGUNTA:
# Como faço para tirar autorização para poda de árvore?
#
# CONTEXTO:
# [PRINCIPAIS_ETAPAS | 1 | Árvore - Denunciar poda ou remoção não autorizada]
# Eletrônico:
#  1) Faça login no Portal de Atendimento SP156 (você já está aqui), clicando na caixa cinza do lado direito da tela ou no final da página. Informe seus dados do SP156 ou entre com o seu Gov.br. Caso não tenha cadastro, faça o seu;2) Após informar seu login, você será direcionado para o formulário de solicitação;3) Preencha o formulário com as informações solicitadas ( para ser direcionado para o formulário diretamente. Lembre-se que é necessário realizar login)e finalize sua solicitação;
#  4) Em seguida, telefone para a Supervisão Técnica de Fiscalização da Subprefeitura da área para verificar a possibilidade dos Agentes Vistores (Fiscais) fazerem o flagrante;
#  5) Entre em contato com a Polícia Militar;
#  6) A solicitação será encaminhada para a Supervisão Técnica de Fiscalização das Subprefeituras;
#  7) O Agente Vistor (Fiscal) da Subprefeitura vistoria o local e constatando a irregularidade, lavra auto de multa para o infrator e o intima a cessar a poda ou corte imediatamente.
#
# ---
# [O_QUE_E | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# É a solicitação de autorização para remoção de árvore(s) com apresentação de Laudo elaborado por Engenheiro Agrônomo/Florestal ou Biólogo contratado pela pessoa interessada.
#
# ---
# [PRINCIPAIS_ETAPAS | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# 1) Solicitar o serviço por meio de algum dos canais de atendimento;
#
# ---
# [LEGISLACAO | 3 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# - Lei Municipal nº 10.365/1987 - Corte e poda de árvores (link direciona para portal externo);
#
# ---
# [CANAIS_PARA_SOLICITAR | 1 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# Eletrônico:
#  - Portal de Atendimento SP156.
#
# ---
# [O_QUE_E | 5 | Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção]
# Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo
#
# ---
# [REQUISITOS_DOCUMENTOS_E_INFORMACOES | 1 | Árvore em área interna - Comunicar poda à Prefeitura]
# Documentos a serementregues para solicitar o serviço:
#  - Documento atualizado que comprove a propriedade ou posse da área privada - cópia digitalizada;
#  - Laudo Técnico elaborado por Engenheiro Agrônomo/Florestal ou Biólogo;
#  - Documento de registro no Conselho pelo profissional responsável pelo Laudo Técnico;
#  - ART do CRBio ou CREA do responsável técnico pela execução do serviço de manejo.
#  - Lista de árvores numeradas com justificativa para o manejo indicado em cada árvore - cópia digitalizada;
#  - Relatório Fotográfico de cada uma das árvores a serem podadas - cópia digitalizada;
#  - Croqui ou planta - cópia digitalizada;
#
# ---
# [LEGISLACAO | 7 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# - Decreto Municipal nº 26.535/1988 - Regulamenta a Lei Municipal nº 10.365/1987, relativa a corte e poda de árvores (link direciona para portal externo).
#
# ---
# [CANAIS_PARA_SOLICITAR | 2 | Árvore em área interna – Solicitar autorização para remoção de árvore com apresentação de laudo]
# Presencial:
#  - Praças de Atendimento das Subprefeituras (endereços das praças de atendimento das Subprefeituras);
#  - Descomplica SP - Atendimento de segunda a sexta-feira, das 8h às 17h (endereços de atendimento do Descomplica SP).
#
# ---
# [LEGISLACAO | 2 | Árvore – Solicitar avaliação em calçadas e praças para fins de poda ou remoção]
# Lei Municipal nº 10.365/1987: corte e poda de árvores(link direciona para portal externo);
#
#
# RESPOSTA:
#
# Para solicitar a autorização para podar uma árvore em área interna, você precisa preencher alguns requisitos:
#
# 1. Acesse o Portal de Atendimento SP156 e faça login.
# 2. Preencha o formulário solicitando a autorização, incluindo:
#    - Documento comprovando propriedade ou posse da área
#    - Laudo Técnico elaborado por Engenheiro Agrônomo/Florestal ou Biólogo
#    - Documento de registro do profissional responsável
#    - ART do CRBio ou CREA do responsável técnico
#    - Lista numerada das árvores com justificativa para o manejo
#    - Relatório fotográfico de cada árvore a ser podada
#    - Croqui ou planta
#
# 3. Entre em contato com os Agentes Vistores (Fiscais) da Subprefeitura para verificar a possibilidade do flagrante.
#
# 4. A solicitação será encaminhada e um Agente Vistor irá verificar o local, lavrando auto de multa se constatar irregularidades, e intimando o infrator a cessar a poda imediatamente.
#
# Caso prefira atendimento presencial, você pode:
# - Ir até as Praças de Atendimento das Subprefeituras
# - Acessar os canais do Descomplica SP
#
# Para mais informações, consulte a Lei Municipal nº 10.365/1987 e o Decreto Municipal nº 26.535/1988 no portal externo fornecido.
