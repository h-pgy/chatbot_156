# %%
from core.scraper.scrape_pipeline import ScrapePipeline

# %%
pipeline = ScrapePipeline()

# %%
df = pipeline()
# Out:
# Scraping service data...
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=animais
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=acessibilidade
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=bilhete-Unico
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=canais-de-atendimento
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=cidadania-e-assistencia-social
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=comercio-e-servicos
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=cultura%2C-esporte-e-lazer
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=documentos-e-licencas
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=educacao
# ...

# %%
df.head()
# Out:
#    permite_pedido_anomimo                                            img_url  \
# 0                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 1                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 2                   False  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 3                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
# 4                    True  https://sigrc.prefeitura.sp.gov.br/assets/medi...
#
#                                         service_desc  service_id  ativo  \
# 0                                Adotar cães e gatos        3676   True
# 1     Pombos - Solicitar vistoria em local infestado         816   True
# 2       Morcegos - Reclamar sobre local com morcegos         815   True
# 3      Ratos - Solicitar vistoria em local infestado         814   True
# 4  Escorpião - Solicitar vistoria de local com es...         813   True
#
#                                      subtheme_name theme_name  \
# ...

# %%
len(df)
# Out:
# 722
