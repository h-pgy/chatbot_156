# %%
from core.scraper.scrape_pipeline import ScrapePipeline

# %%
pipeline = ScrapePipeline()

# %%
pipeline()
# Out:
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online
# /home/hpougy/projects/chatbot_156/core/scraper/service_theme_list.py:16: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 16 of the file /home/hpougy/projects/chatbot_156/core/scraper/service_theme_list.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   return BeautifulSoup(page_html)
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=animais
# Getting html for https://sp156.prefeitura.sp.gov.br/portal/servicos-online?id=acessibilidade
# ...
